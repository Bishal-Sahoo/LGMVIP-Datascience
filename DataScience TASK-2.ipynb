# %% [markdown]
# # LETS GROW MORE
#
# <B> NAME : BISHAL SAHOO
#
# # Data Science Intern
#
# <B> TASK-4: IMAGE TO PENCIL SKETCH WITH PYTHON
#
# <B> BATCH : FEBRUARY 2021
#
# <B> DESCRIPTION OF TASK:
#
#     We need to read the image in RBG format and then convert it to a grayscale image. This will turn     an image into a classic black and white photo. Then the next thing to do is invert the grayscale     image also called negative image,this will be our inverted grayscale image.Inversion can be used     to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image       with the inverted blury image. This can be done by dividing the grayscale image by the inverted       blury image.

# %%
# !pip install opencv-python

# %%
import cv2

# %%
image=cv2.imread("desktop/dog.jpg")

# %%
cv2.imshow("Dog",image)
cv2.waitKey(0)
# Out:
# -1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(img_rgb)

# %%
gray_image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[ 41,  43,  45, ..., 248, 247, 247],
#        [ 43,  45,  48, ..., 247, 247, 247],
#        [ 47,  48,  51, ..., 247, 247, 247],
#        ...,
#        [129, 129, 130, ..., 202, 202, 202],
#        [130, 131, 131, ..., 203, 203, 203],
#        [131, 132, 132, ..., 203, 203, 203]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %%
inverted_image = 255 - gray_image
plt.imshow(inverted_image)

# %%
blurred=cv2.GaussianBlur(inverted_image,(21,21),0)
plt.imshow(blurred)

# %%
inverted_blurred = 255-blurred
pencil_sketch = cv2.divide(gray_image,inverted_blurred,scale=256.0)
plt.imshow(pencil_sketch)

# %%
cv2.imshow("Dog Sketch",pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow("original image",image)
cv2.imshow("pencil sketch",pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
